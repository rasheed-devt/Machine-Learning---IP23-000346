# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import copy
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %% [markdown]
# # Loading train data

# %%
train_data = pd.read_excel("Train Data.xlsx")

# %% [markdown]
# # Data Inspection

# %%
train_data.head()
# Out:
#   First Name           Email ID  Quantity  Price Tier             Ticket Type  \
# 0     ANIKET     aniket@xyz.com         1         NaN  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1         NaN  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1         NaN  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1         NaN  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1         NaN  Art of Resume Building
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.213855e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.213859e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.213862e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.213988e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.214567e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                         College Name  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Don Bosco College of Engineering Fatorda Goa
# 3           Pillai College of Engineering New Panvel
# 4                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# 3                                            Email
# 4  Instagram | LinkedIn | Cloud Counselage Website
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                            College                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  6.7               2            5            Placed
# 1                NaN  8.2               3            2        Not placed
# 2                NaN  6.5               4            3        Not placed
# 3                NaN  8.7               2            5        Not placed
# 4                NaN  9.1               3            5            Placed
#
# [5 rows x 23 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4894 entries, 0 to 4893
# Data columns (total 23 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   First Name                                                       4894 non-null   object
#  1   Email ID                                                         4894 non-null   object
#  2   Quantity                                                         4894 non-null   int64
#  3   Price Tier                                                       0 non-null      float64
#  4   Ticket Type                                                      4894 non-null   object
#  5   Attendee #                                                       4490 non-null   float64
#  6   Group                                                            0 non-null      float64
#  7   Order Type                                                       4894 non-null   object
#  8   Currency                                                         4490 non-null   object
#  9   Total Paid                                                       4894 non-null   int64
#  10  Fees Paid                                                        4490 non-null   float64
#  11  Eventbrite Fees                                                  4894 non-null   int64
#  12  Eventbrite Payment Processing                                    4894 non-null   int64
#  13  Attendee Status                                                  4894 non-null   object
#  14  College Name                                                     4879 non-null   object
#  15  How did you come to know about this event?                       2678 non-null   object
#  16  Specify in "Others" (how did you come to know about this event)  89 non-null     object
#  17  Designation                                                      4894 non-null   object
#  18  Year of Graduation                                               1032 non-null   object
#  19  CGPA                                                             4894 non-null   float64
#  20  Speaking Skills                                                  4894 non-null   int64
#  21  ML Knowledge                                                     4894 non-null   int64
#  22  Placement Status                                                 1098 non-null   object
# dtypes: float64(5), int64(6), object(12)
# memory usage: 879.5+ KB

# %% [markdown]
# # Identifing and locating missing values

# %%
missing_data = train_data.isnull().sum()

# %%
missing_data
# Out:
# First Name                                                            0
# Email ID                                                              0
# Quantity                                                              0
# Price Tier                                                         4894
# Ticket Type                                                           0
# Attendee #                                                          404
# Group                                                              4894
# Order Type                                                            0
# Currency                                                            404
# Total Paid                                                            0
# Fees Paid                                                           404
# Eventbrite Fees                                                       0
# Eventbrite Payment Processing                                         0
# Attendee Status                                                       0
# College Name                                                         15
# How did you come to know about this event?                         2216
# Specify in "Others" (how did you come to know about this event)    4805
# Designation                                                           0
# Year of Graduation                                                 3862
# CGPA                                                                  0
# Speaking Skills                                                       0
# ML Knowledge                                                          0
# Placement Status                                                   3796
# dtype: int64

# %% [markdown]
# # Cleaning the data using emails

# %%
train_data = train_data.drop_duplicates(subset=["Email ID"])

# %%
train_data.head()
# Out:
#   First Name           Email ID  Quantity  Price Tier             Ticket Type  \
# 0     ANIKET     aniket@xyz.com         1         NaN  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1         NaN  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1         NaN  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1         NaN  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1         NaN  Art of Resume Building
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.213855e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.213859e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.213862e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.213988e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.214567e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                         College Name  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Don Bosco College of Engineering Fatorda Goa
# 3           Pillai College of Engineering New Panvel
# 4                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# 3                                            Email
# 4  Instagram | LinkedIn | Cloud Counselage Website
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                            College                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  6.7               2            5            Placed
# 1                NaN  8.2               3            2        Not placed
# 2                NaN  6.5               4            3        Not placed
# 3                NaN  8.7               2            5        Not placed
# 4                NaN  9.1               3            5            Placed
#
# [5 rows x 23 columns]

# %% [markdown]
# # Creating deep copies of your dataframe

# %%
train_data_backup = copy.deepcopy(train_data)

# %%
train_data_backup.head()
# Out:
#   First Name           Email ID  Quantity  Price Tier             Ticket Type  \
# 0     ANIKET     aniket@xyz.com         1         NaN  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1         NaN  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1         NaN  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1         NaN  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1         NaN  Art of Resume Building
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.213855e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.213859e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.213862e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.213988e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.214567e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                         College Name  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Don Bosco College of Engineering Fatorda Goa
# 3           Pillai College of Engineering New Panvel
# 4                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# 3                                            Email
# 4  Instagram | LinkedIn | Cloud Counselage Website
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                            College                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  6.7               2            5            Placed
# 1                NaN  8.2               3            2        Not placed
# 2                NaN  6.5               4            3        Not placed
# 3                NaN  8.7               2            5        Not placed
# 4                NaN  9.1               3            5            Placed
#
# [5 rows x 23 columns]

# %% [markdown]
# # Selecting only useful columns

# %%
useful_columns = ["Ticket Type", "Attendee #", "Attendee Status", "College Name",
                  "Designation", "Year of Graduation", "CGPA", "Speaking Skills", 
                  "ML Knowledge", "Placement Status"]

train_data = train_data[useful_columns]

# %%
train_data.head()
# Out:
#               Ticket Type    Attendee # Attendee Status  \
# 0  Art of Resume Building  2.213855e+09       Attending
# 1  Art of Resume Building  2.213859e+09       Attending
# 2  Art of Resume Building  2.213862e+09       Attending
# 3  Art of Resume Building  2.213988e+09       Attending
# 4  Art of Resume Building  2.214567e+09       Attending
#
#                                         College Name Designation  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...    Students
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY     Students
# 2       Don Bosco College of Engineering Fatorda Goa    Students
# 3           Pillai College of Engineering New Panvel    Students
# 4                               St Xavier's College     Students
#
#   Year of Graduation  CGPA  Speaking Skills  ML Knowledge Placement Status
# 0                NaN   6.7                2             5           Placed
# 1                NaN   8.2                3             2       Not placed
# 2                NaN   6.5                4             3       Not placed
# 3                NaN   8.7                2             5       Not placed
# 4                NaN   9.1                3             5           Placed

# %% [markdown]
# # Imputation for numerical columns

# %%
numerical_columns = train_data.select_dtypes(include=['int64', 'float64']).columns
numerical_imputer = SimpleImputer(strategy='mean')
train_data[numerical_columns] = numerical_imputer.fit_transform(train_data[numerical_columns])

# %% [markdown]
# # Data Scaling and Transformation

# %%
scaler = StandardScaler()
train_data[numerical_columns] = scaler.fit_transform(train_data[numerical_columns])

# %% [markdown]
# # Converting categorical columns to numeric using Label Encoding

# %%
categorical_columns = ["Ticket Type", "Attendee Status",
                       "College Name", "Designation", "Year of Graduation",
                       "Placement Status"]

for column in categorical_columns:
    le = LabelEncoder()
    train_data[column] = le.fit_transform(train_data[column])

# %%
train_data[column]
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4829    2
# 4831    2
# 4832    2
# 4834    2
# 4836    2
# Name: Placement Status, Length: 1987, dtype: int32

# %%
train_data
# Out:
#       Ticket Type  Attendee #  Attendee Status  College Name  Designation  \
# 0               0   -0.376180                0             5           32
# 1               0   -0.376175                0             2           32
# 2               0   -0.376171                0             7           32
# 3               0   -0.376003                0            16           32
# 4               0   -0.375231                0            20           32
# ...           ...         ...              ...           ...          ...
# 4829           15   -0.352786                0            44           32
# 4831           15   -0.352744                0            52           32
# 4832           15   -0.352733                0            36           32
# 4834           15   -0.352678                0            53           32
# 4836           15   -0.352592                0            45           32
#
#       Year of Graduation      CGPA  Speaking Skills  ML Knowledge  \
# 0                     17 -1.320958        -1.160881      1.326843
# 1                     17  0.172014        -0.330247     -1.175312
# 2                     17 -1.520021         0.500387     -0.341260
# 3                     17  0.669671        -1.160881      1.326843
# 4                     17  1.067796        -0.330247      1.326843
# ...                  ...       ...              ...           ...
# 4829                  17  1.067796         1.331021      0.492791
# 4831                  17 -0.624238        -0.330247     -1.175312
# 4832                  17 -0.723769         0.500387      0.492791
# 4834                  17  1.167328         0.500387     -1.175312
# 4836                  17 -0.126581        -1.160881      1.326843
#
#       Placement Status
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# ...                ...
# 4829                 2
# 4831                 2
# 4832                 2
# 4834                 2
# 4836                 2
#
# [1987 rows x 10 columns]

# %% [markdown]
# # Separating features (x_train) and target (y_train)

# %%
x = train_data.drop("Placement Status", axis=1)
y = train_data["Placement Status"]

# %%
x
# Out:
#       Ticket Type  Attendee #  Attendee Status  College Name  Designation  \
# 0               0   -0.376180                0             5           32
# 1               0   -0.376175                0             2           32
# 2               0   -0.376171                0             7           32
# 3               0   -0.376003                0            16           32
# 4               0   -0.375231                0            20           32
# ...           ...         ...              ...           ...          ...
# 4829           15   -0.352786                0            44           32
# 4831           15   -0.352744                0            52           32
# 4832           15   -0.352733                0            36           32
# 4834           15   -0.352678                0            53           32
# 4836           15   -0.352592                0            45           32
#
#       Year of Graduation      CGPA  Speaking Skills  ML Knowledge
# 0                     17 -1.320958        -1.160881      1.326843
# 1                     17  0.172014        -0.330247     -1.175312
# 2                     17 -1.520021         0.500387     -0.341260
# 3                     17  0.669671        -1.160881      1.326843
# 4                     17  1.067796        -0.330247      1.326843
# ...                  ...       ...              ...           ...
# 4829                  17  1.067796         1.331021      0.492791
# 4831                  17 -0.624238        -0.330247     -1.175312
# 4832                  17 -0.723769         0.500387      0.492791
# 4834                  17  1.167328         0.500387     -1.175312
# 4836                  17 -0.126581        -1.160881      1.326843
#
# [1987 rows x 9 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 4829    2
# 4831    2
# 4832    2
# 4834    2
# 4836    2
# Name: Placement Status, Length: 1987, dtype: int32

# %% [markdown]
# # Spliting the data into train and validation sets

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Model that can handle missing values natively

# %%
model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Loading test data

# %%
test_data = pd.read_excel("Test Data.xlsx")

# %% [markdown]
# # Data Inspection

# %%
test_data.head()
# Out:
#    First Name            Email ID  Quantity  Price Tier      Ticket Type  \
# 0      Sahil        sahil@xyz.com         1         NaN  Hello ML and DL
# 1     Amrita       amrita@xyz.com         1         NaN  Hello ML and DL
# 2       Mamta       mamta@xyz.com         1         NaN  Hello ML and DL
# 3  Bhagyashri  bhagyashri@xyz.com         1         NaN  Hello ML and DL
# 4   Divyanshu   divyanshu@xyz.com         1         NaN  Hello ML and DL
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.293940e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.293946e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.293956e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                      College Name  \
# 0         symbiosis institute of technology, pune
# 1              mit academy of engineering ,alandi
# 2              a. c. patil college of engineering
# 3                                 wilson college
# 4  ld college of engineering, ahmedabad, gujarat
#
#    How did you come to know about this event?  \
# 0                                    Whatsapp
# 1                                    Whatsapp
# 2                                    Whatsapp
# 3                                      Others
# 4                                    Whatsapp
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                                NaN                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  7.8               3            3               NaN
# 1                NaN  9.1               3            3               NaN
# 2                NaN  6.9               2            2               NaN
# 3                NaN  8.4               4            4               NaN
# 4                NaN  6.7               5            5               NaN
#
# [5 rows x 23 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3796 entries, 0 to 3795
# Data columns (total 23 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   First Name                                                       3796 non-null   object
#  1   Email ID                                                         3796 non-null   object
#  2   Quantity                                                         3796 non-null   int64
#  3   Price Tier                                                       0 non-null      float64
#  4   Ticket Type                                                      3796 non-null   object
#  5   Attendee #                                                       3794 non-null   float64
#  6   Group                                                            0 non-null      float64
#  7   Order Type                                                       3796 non-null   object
#  8   Currency                                                         3794 non-null   object
#  9   Total Paid                                                       3796 non-null   int64
#  10  Fees Paid                                                        3794 non-null   float64
#  11  Eventbrite Fees                                                  3796 non-null   int64
#  12  Eventbrite Payment Processing                                    3796 non-null   int64
#  13  Attendee Status                                                  3796 non-null   object
#  14  College Name                                                     3795 non-null   object
#  15  How did you come to know about this event?                       1584 non-null   object
#  16  Specify in "Others" (how did you come to know about this event)  27 non-null     object
#  17  Designation                                                      3796 non-null   object
#  18  Year of Graduation                                               1032 non-null   object
#  19  CGPA                                                             3796 non-null   float64
#  20  Speaking Skills                                                  3796 non-null   int64
#  21  ML Knowledge                                                     3796 non-null   int64
#  22  Placement Status                                                 0 non-null      float64
# dtypes: float64(6), int64(6), object(11)
# memory usage: 682.2+ KB

# %% [markdown]
# # Identifing and locating missing values

# %%
missing_data = test_data.isnull().sum()

# %%
missing_data
# Out:
# First Name                                                            0
# Email ID                                                              0
# Quantity                                                              0
# Price Tier                                                         3796
# Ticket Type                                                           0
# Attendee #                                                            2
# Group                                                              3796
# Order Type                                                            0
# Currency                                                              2
# Total Paid                                                            0
# Fees Paid                                                             2
# Eventbrite Fees                                                       0
# Eventbrite Payment Processing                                         0
# Attendee Status                                                       0
# College Name                                                          1
# How did you come to know about this event?                         2212
# Specify in "Others" (how did you come to know about this event)    3769
# Designation                                                           0
# Year of Graduation                                                 2764
# CGPA                                                                  0
# Speaking Skills                                                       0
# ML Knowledge                                                          0
# Placement Status                                                   3796
# dtype: int64

# %% [markdown]
# # Cleaning the data using emails

# %%
test_data = test_data.drop_duplicates(subset=["Email ID"])

# %%
test_data.head()
# Out:
#    First Name            Email ID  Quantity  Price Tier      Ticket Type  \
# 0      Sahil        sahil@xyz.com         1         NaN  Hello ML and DL
# 1     Amrita       amrita@xyz.com         1         NaN  Hello ML and DL
# 2       Mamta       mamta@xyz.com         1         NaN  Hello ML and DL
# 3  Bhagyashri  bhagyashri@xyz.com         1         NaN  Hello ML and DL
# 4   Divyanshu   divyanshu@xyz.com         1         NaN  Hello ML and DL
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.293940e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.293946e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.293956e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                      College Name  \
# 0         symbiosis institute of technology, pune
# 1              mit academy of engineering ,alandi
# 2              a. c. patil college of engineering
# 3                                 wilson college
# 4  ld college of engineering, ahmedabad, gujarat
#
#    How did you come to know about this event?  \
# 0                                    Whatsapp
# 1                                    Whatsapp
# 2                                    Whatsapp
# 3                                      Others
# 4                                    Whatsapp
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                                NaN                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  7.8               3            3               NaN
# 1                NaN  9.1               3            3               NaN
# 2                NaN  6.9               2            2               NaN
# 3                NaN  8.4               4            4               NaN
# 4                NaN  6.7               5            5               NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # Creating deep copies of your dataframe

# %%
test_data_backup = copy.deepcopy(test_data)

# %%
test_data_backup.head()
# Out:
#    First Name            Email ID  Quantity  Price Tier      Ticket Type  \
# 0      Sahil        sahil@xyz.com         1         NaN  Hello ML and DL
# 1     Amrita       amrita@xyz.com         1         NaN  Hello ML and DL
# 2       Mamta       mamta@xyz.com         1         NaN  Hello ML and DL
# 3  Bhagyashri  bhagyashri@xyz.com         1         NaN  Hello ML and DL
# 4   Divyanshu   divyanshu@xyz.com         1         NaN  Hello ML and DL
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.293940e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.293946e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.293956e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                      College Name  \
# 0         symbiosis institute of technology, pune
# 1              mit academy of engineering ,alandi
# 2              a. c. patil college of engineering
# 3                                 wilson college
# 4  ld college of engineering, ahmedabad, gujarat
#
#    How did you come to know about this event?  \
# 0                                    Whatsapp
# 1                                    Whatsapp
# 2                                    Whatsapp
# 3                                      Others
# 4                                    Whatsapp
#
#   Specify in "Others" (how did you come to know about this event) Designation  \
# 0                                                NaN                 Students
# 1                                                NaN                 Students
# 2                                                NaN                 Students
# 3                                                NaN                 Students
# 4                                                NaN                 Students
#
#   Year of Graduation CGPA Speaking Skills ML Knowledge  Placement Status
# 0                NaN  7.8               3            3               NaN
# 1                NaN  9.1               3            3               NaN
# 2                NaN  6.9               2            2               NaN
# 3                NaN  8.4               4            4               NaN
# 4                NaN  6.7               5            5               NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # Selecting only useful columns

# %%
useful_columns = ["Ticket Type", "Attendee #", "Attendee Status", "College Name",
                  "Designation", "Year of Graduation", "CGPA", "Speaking Skills", "ML Knowledge"]

test_data = test_data[useful_columns]

# %%
test_data.head()
# Out:
#        Ticket Type    Attendee # Attendee Status  \
# 0  Hello ML and DL  2.293940e+09       Attending
# 1  Hello ML and DL  2.293941e+09       Attending
# 2  Hello ML and DL  2.293941e+09       Attending
# 3  Hello ML and DL  2.293946e+09       Attending
# 4  Hello ML and DL  2.293956e+09       Attending
#
#                                      College Name Designation  \
# 0         symbiosis institute of technology, pune    Students
# 1              mit academy of engineering ,alandi    Students
# 2              a. c. patil college of engineering    Students
# 3                                 wilson college     Students
# 4  ld college of engineering, ahmedabad, gujarat     Students
#
#   Year of Graduation  CGPA  Speaking Skills  ML Knowledge
# 0                NaN   7.8                3             3
# 1                NaN   9.1                3             3
# 2                NaN   6.9                2             2
# 3                NaN   8.4                4             4
# 4                NaN   6.7                5             5

# %% [markdown]
# # Imputation for numerical columns

# %%
numerical_columns = test_data.select_dtypes(include=['int64', 'float64']).columns
numerical_imputer = SimpleImputer(strategy='mean')
test_data[numerical_columns] = numerical_imputer.fit_transform(test_data[numerical_columns])

# %% [markdown]
# # Data Scaling and Transformation

# %%
scaler = StandardScaler()
test_data[numerical_columns] = scaler.fit_transform(test_data[numerical_columns])

# %% [markdown]
# # Converting categorical columns to numeric using Label Encoding

# %%
categorical_columns = ["Ticket Type", "Attendee Status",
                       "College Name", "Designation", "Year of Graduation"
                       ]

for column in categorical_columns:
    le = LabelEncoder()
    test_data[column] = le.fit_transform(test_data[column])

# %%
test_data[column]
# Out:
# 0       22
# 1       22
# 2       22
# 3       22
# 4       22
#         ..
# 3685    22
# 3687    22
# 3692    22
# 3693    22
# 3695    22
# Name: Year of Graduation, Length: 2321, dtype: int32

# %%
test_data
# Out:
#       Ticket Type  Attendee #  Attendee Status  College Name  Designation  \
# 0               0   -0.269321                0            49           46
# 1               0   -0.269321                0            41           46
# 2               0   -0.269320                0            27           46
# 3               0   -0.269316                0            53           46
# 4               0   -0.269304                0            39           46
# ...           ...         ...              ...           ...          ...
# 3685           11   -0.339259                0            34           46
# 3687           11   -0.338720                0            47           46
# 3692           11   -0.338606                0            33           46
# 3693           11   -0.338598                0            39           46
# 3695           11   -0.338557                0            36           46
#
#       Year of Graduation      CGPA  Speaking Skills  ML Knowledge
# 0                     22 -0.233957        -0.254328     -0.240896
# 1                     22  1.071365        -0.254328     -0.240896
# 2                     22 -1.137641        -1.076466     -1.061922
# 3                     22  0.368499         0.567810      0.580131
# 4                     22 -1.338460         1.389948      1.401157
# ...                  ...       ...              ...           ...
# 3685                  22 -0.033138        -0.254328     -0.240896
# 3687                  22  0.468909         1.389948      1.401157
# 3692                  22  0.770137        -0.254328     -0.240896
# 3693                  22  1.272184         0.567810      0.580131
# 3695                  22 -1.539279         0.567810      0.580131
#
# [2321 rows x 9 columns]

# %% [markdown]
# # Model Evaluation

# %%
y_pred = model.predict(x_val)
accuracy = accuracy_score(y_val, y_pred)
print("Validation Accuracy:", accuracy)
# Out:
# Validation Accuracy: 0.8467336683417085

# %% [markdown]
# # Calculate precision and recall

# %%
precision = precision_score(y_val, y_pred, average='weighted')
recall = recall_score(y_val, y_pred, average='weighted')
print("Validation Precision:", precision)
print("Validation Recall:", recall)
# Out:
# Validation Precision: 0.8222535602915765
# Validation Recall: 0.8467336683417085

# %% [markdown]
# # Making predictions on test data

# %%
predictions = model.predict(test_data)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
y_true_test = test_data_backup["Placement Status"]

# %%
test_data_backup["Placement Status"].fillna(0, inplace=True)
y_true_test = test_data_backup["Placement Status"]

# %%
accuracy_test = accuracy_score(y_true_test, predictions)
precision_test = precision_score(y_true_test, predictions, average='weighted')
recall_test = recall_score(y_true_test, predictions, average='weighted', zero_division=0)

print("Test Accuracy:", accuracy_test)
print("Test Precision:", precision_test)
print("Test Recall:", recall_test)
# Out:
# Test Accuracy: 0.06204222317966394
# Test Precision: 1.0
# Test Recall: 0.06204222317966394

# %% [markdown]
# # Saving predictions to a separate excel file

# %%
output_df = pd.DataFrame({"First Name": test_data_backup["First Name"], "Email ID": test_data_backup["Email ID"], **test_data, "Placement Status": predictions})
output_df.to_excel("Prediction of Placement Status.xlsx", index=False)
